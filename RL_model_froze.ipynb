# %%
import os, argparse
import tensorflow as tf

def freeze_graph(model_dir, output_node_names):
    """Extract the sub graph defined by the output nodes and convert 
    all its variables into constant 
    Args:
        model_dir: the root folder containing the checkpoint state file
        output_node_names: a string, containing all the output node's names, 
                            comma separated
    """
    if not tf.gfile.Exists(model_dir):
        raise AssertionError(
            "Export directory doesn't exists. Please specify an export "
            "directory: %s" % model_dir)

    if not output_node_names:
        print("You need to supply the name of a node to --output_node_names.")
        return -1

    # We retrieve our checkpoint fullpath
    checkpoint = tf.train.get_checkpoint_state(model_dir)
    input_checkpoint = checkpoint.model_checkpoint_path
    
    # We precise the file fullname of our freezed graph
    absolute_model_dir = "/".join(input_checkpoint.split('/')[:-1])
    output_graph = absolute_model_dir + "/frozen_model.pb"

    # We clear devices to allow TensorFlow to control on which device it will load operations
    clear_devices = True

    # We start a session using a temporary fresh Graph
    with tf.Session(graph=tf.Graph()) as sess:
        # We import the meta graph in the current default Graph
        saver = tf.train.import_meta_graph(input_checkpoint + '.meta', clear_devices=clear_devices)

        # We restore the weights
        saver.restore(sess, input_checkpoint)
        
        graph = tf.get_default_graph() 
        #print("graph: " + str(graph))
        
        #for n in tf.get_default_graph().as_graph_def().node:
        #    print("n.name : " + str(n.name))
        
        # We use a built-in TF helper to export variables to constants
        output_graph_def = tf.graph_util.convert_variables_to_constants(
            sess, # The session is used to retrieve the weights
            tf.get_default_graph().as_graph_def(), # The graph_def is used to retrieve the nodes 
            output_node_names.split(",") # The output node names are used to select the usefull nodes
        ) 

        # Finally we serialize and dump the output graph to the filesystem
        with tf.gfile.GFile(output_graph, "wb") as f:
            f.write(output_graph_def.SerializeToString())
            
        print("%d ops in the final graph." % len(output_graph_def.node))

    return output_graph_def

if __name__ == '__main__':
    #parser = argparse.ArgumentParser()
    #parser.add_argument("--model_dir", type=str, default="/home/kimbring2/catkin_ws/src/jetbot/jetbot_control/src/drqn", help="Model folder to export")
    #parser.add_argument("--output_node_names", type=str, default="jetbot_frozen_model", help="The name of the output nodes, comma separated.")
    #args = parser.parse_args()
    
    model_dir = "/home/kimbring2/catkin_ws/src/jetbot/jetbot_control/src/drqn"
    output_node_names = "main/ArgMax"
    freeze_graph(model_dir, output_node_names)
# Out:
# INFO:tensorflow:Restoring parameters from /home/kimbring2/catkin_ws/src/jetbot/jetbot_control/src/drqn/model-2.cptk
# n.name : main/scalarInput
# n.name : main/Reshape/shape
# n.name : main/Reshape
# n.name : main/Conv/weights/Initializer/random_uniform/shape
# n.name : main/Conv/weights/Initializer/random_uniform/min
# n.name : main/Conv/weights/Initializer/random_uniform/max
# n.name : main/Conv/weights/Initializer/random_uniform/RandomUniform
# n.name : main/Conv/weights/Initializer/random_uniform/sub
# n.name : main/Conv/weights/Initializer/random_uniform/mul
# n.name : main/Conv/weights/Initializer/random_uniform
# n.name : main/Conv/weights
# n.name : main/Conv/weights/Assign
# n.name : main/Conv/weights/read
# n.name : main/Conv/dilation_rate
# n.name : main/Conv/Conv2D
# n.name : main/Conv/Relu
# n.name : main/Conv_1/weights/Initializer/random_uniform/shape
# n.name : main/Conv_1/weights/Initializer/random_uniform/min
# n.name : main/Conv_1/weights/Initializer/random_uniform/max
# n.name : main/Conv_1/weights/Initializer/random_uniform/RandomUniform
# n.name : main/Conv_1/weights/Initializer/random_uniform/sub
# n.name : main/Conv_1/weights/Initializer/random_uniform/mul
# n.name : main/Conv_1/weights/Initializer/random_uniform
# n.name : main/Conv_1/weights
# n.name : main/Conv_1/weights/Assign
# n.name : main/Conv_1/weights/read
# n.name : main/Conv_1/dilation_rate
# n.name : main/Conv_1/Conv2D
# n.name : main/Conv_1/Relu
# n.name : main/Conv_2/weights/Initializer/random_uniform/shape
# n.name : main/Conv_2/weights/Initializer/random_uniform/min
# n.name : main/Conv_2/weights/Initializer/random_uniform/max
# n.name : main/Conv_2/weights/Initializer/random_uniform/RandomUniform
# n.name : main/Conv_2/weights/Initializer/random_uniform/sub
# n.name : main/Conv_2/weights/Initializer/random_uniform/mul
# n.name : main/Conv_2/weights/Initializer/random_uniform
# n.name : main/Conv_2/weights
# n.name : main/Conv_2/weights/Assign
# n.name : main/Conv_2/weights/read
# n.name : main/Conv_2/dilation_rate
# n.name : main/Conv_2/Conv2D
# n.name : main/Conv_2/Relu
# n.name : main/Conv_3/weights/Initializer/random_uniform/shape
# n.name : main/Conv_3/weights/Initializer/random_uniform/min
# n.name : main/Conv_3/weights/Initializer/random_uniform/max
# n.name : main/Conv_3/weights/Initializer/random_uniform/RandomUniform
# n.name : main/Conv_3/weights/Initializer/random_uniform/sub
# n.name : main/Conv_3/weights/Initializer/random_uniform/mul
# n.name : main/Conv_3/weights/Initializer/random_uniform
# n.name : main/Conv_3/weights
# n.name : main/Conv_3/weights/Assign
# n.name : main/Conv_3/weights/read
# n.name : main/Conv_3/dilation_rate
# n.name : main/Conv_3/Conv2D
# n.name : main/Conv_3/Relu
# n.name : main/trainLength
# n.name : main/batch_size
# n.name : main/Flatten/flatten/Shape
# n.name : main/Flatten/flatten/strided_slice/stack
# n.name : main/Flatten/flatten/strided_slice/stack_1
# n.name : main/Flatten/flatten/strided_slice/stack_2
# n.name : main/Flatten/flatten/strided_slice
# n.name : main/Flatten/flatten/Reshape/shape/1
# n.name : main/Flatten/flatten/Reshape/shape
# n.name : main/Flatten/flatten/Reshape
# n.name : main/Reshape_1/shape/2
# n.name : main/Reshape_1/shape
# n.name : main/Reshape_1
# n.name : main/BasicLSTMCellZeroState/ExpandDims/dim
# n.name : main/BasicLSTMCellZeroState/ExpandDims
# n.name : main/BasicLSTMCellZeroState/Const
# n.name : main/BasicLSTMCellZeroState/concat/axis
# n.name : main/BasicLSTMCellZeroState/concat
# n.name : main/BasicLSTMCellZeroState/zeros/Const
# n.name : main/BasicLSTMCellZeroState/zeros
# n.name : main/BasicLSTMCellZeroState/ExpandDims_1/dim
# n.name : main/BasicLSTMCellZeroState/ExpandDims_1
# n.name : main/BasicLSTMCellZeroState/Const_1
# n.name : main/BasicLSTMCellZeroState/ExpandDims_2/dim
# n.name : main/BasicLSTMCellZeroState/ExpandDims_2
# n.name : main/BasicLSTMCellZeroState/Const_2
# n.name : main/BasicLSTMCellZeroState/concat_1/axis
# n.name : main/BasicLSTMCellZeroState/concat_1
# n.name : main/BasicLSTMCellZeroState/zeros_1/Const
# n.name : main/BasicLSTMCellZeroState/zeros_1
# n.name : main/BasicLSTMCellZeroState/ExpandDims_3/dim
# n.name : main/BasicLSTMCellZeroState/ExpandDims_3
# n.name : main/BasicLSTMCellZeroState/Const_3
# n.name : main/rnn/Rank
# n.name : main/rnn/range/start
# n.name : main/rnn/range/delta
# n.name : main/rnn/range
# n.name : main/rnn/concat/values_0
# n.name : main/rnn/concat/axis
# n.name : main/rnn/concat
# n.name : main/rnn/transpose
# n.name : main/rnn/Shape
# n.name : main/rnn/strided_slice/stack
# n.name : main/rnn/strided_slice/stack_1
# n.name : main/rnn/strided_slice/stack_2
# n.name : main/rnn/strided_slice
# n.name : main/rnn/Shape_1
# n.name : main/rnn/strided_slice_1/stack
# n.name : main/rnn/strided_slice_1/stack_1
# n.name : main/rnn/strided_slice_1/stack_2
# n.name : main/rnn/strided_slice_1
# n.name : main/rnn/Shape_2
# n.name : main/rnn/strided_slice_2/stack
# n.name : main/rnn/strided_slice_2/stack_1
# n.name : main/rnn/strided_slice_2/stack_2
# n.name : main/rnn/strided_slice_2
# n.name : main/rnn/ExpandDims/dim
# n.name : main/rnn/ExpandDims
# n.name : main/rnn/Const
# n.name : main/rnn/concat_1/axis
# n.name : main/rnn/concat_1
# n.name : main/rnn/zeros/Const
# n.name : main/rnn/zeros
# n.name : main/rnn/time
# n.name : main/rnn/TensorArray
# n.name : main/rnn/TensorArray_1
# n.name : main/rnn/TensorArrayUnstack/Shape
# n.name : main/rnn/TensorArrayUnstack/strided_slice/stack
# n.name : main/rnn/TensorArrayUnstack/strided_slice/stack_1
# n.name : main/rnn/TensorArrayUnstack/strided_slice/stack_2
# n.name : main/rnn/TensorArrayUnstack/strided_slice
# n.name : main/rnn/TensorArrayUnstack/range/start
# n.name : main/rnn/TensorArrayUnstack/range/delta
# n.name : main/rnn/TensorArrayUnstack/range
# n.name : main/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3
# n.name : main/rnn/Maximum/x
# n.name : main/rnn/Maximum
# n.name : main/rnn/Minimum
# n.name : main/rnn/while/iteration_counter
# n.name : main/rnn/while/Enter
# n.name : main/rnn/while/Enter_1
# n.name : main/rnn/while/Enter_2
# n.name : main/rnn/while/Enter_3
# n.name : main/rnn/while/Enter_4
# n.name : main/rnn/while/Merge
# n.name : main/rnn/while/Merge_1
# n.name : main/rnn/while/Merge_2
# n.name : main/rnn/while/Merge_3
# n.name : main/rnn/while/Merge_4
# n.name : main/rnn/while/Less/Enter
# n.name : main/rnn/while/Less
# n.name : main/rnn/while/Less_1/Enter
# n.name : main/rnn/while/Less_1
# n.name : main/rnn/while/LogicalAnd
# n.name : main/rnn/while/LoopCond
# n.name : main/rnn/while/Switch
# n.name : main/rnn/while/Switch_1
# n.name : main/rnn/while/Switch_2
# n.name : main/rnn/while/Switch_3
# n.name : main/rnn/while/Switch_4
# n.name : main/rnn/while/Identity
# n.name : main/rnn/while/Identity_1
# n.name : main/rnn/while/Identity_2
# n.name : main/rnn/while/Identity_3
# n.name : main/rnn/while/Identity_4
# n.name : main/rnn/while/add/y
# n.name : main/rnn/while/add
# n.name : main/rnn/while/TensorArrayReadV3/Enter
# n.name : main/rnn/while/TensorArrayReadV3/Enter_1
# n.name : main/rnn/while/TensorArrayReadV3
# n.name : main/rnn/basic_lstm_cell/kernel/Initializer/random_uniform/shape
# n.name : main/rnn/basic_lstm_cell/kernel/Initializer/random_uniform/min
# n.name : main/rnn/basic_lstm_cell/kernel/Initializer/random_uniform/max
# n.name : main/rnn/basic_lstm_cell/kernel/Initializer/random_uniform/RandomUniform
# n.name : main/rnn/basic_lstm_cell/kernel/Initializer/random_uniform/sub
# n.name : main/rnn/basic_lstm_cell/kernel/Initializer/random_uniform/mul
# n.name : main/rnn/basic_lstm_cell/kernel/Initializer/random_uniform
# n.name : main/rnn/basic_lstm_cell/kernel
# n.name : main/rnn/basic_lstm_cell/kernel/Assign
# n.name : main/rnn/basic_lstm_cell/kernel/read
# n.name : main/rnn/basic_lstm_cell/bias/Initializer/zeros/shape_as_tensor
# n.name : main/rnn/basic_lstm_cell/bias/Initializer/zeros/Const
# n.name : main/rnn/basic_lstm_cell/bias/Initializer/zeros
# n.name : main/rnn/basic_lstm_cell/bias
# n.name : main/rnn/basic_lstm_cell/bias/Assign
# n.name : main/rnn/basic_lstm_cell/bias/read
# n.name : main/rnn/while/basic_lstm_cell/Const
# n.name : main/rnn/while/basic_lstm_cell/concat/axis
# n.name : main/rnn/while/basic_lstm_cell/concat
# n.name : main/rnn/while/basic_lstm_cell/MatMul/Enter
# n.name : main/rnn/while/basic_lstm_cell/MatMul
# n.name : main/rnn/while/basic_lstm_cell/BiasAdd/Enter
# n.name : main/rnn/while/basic_lstm_cell/BiasAdd
# n.name : main/rnn/while/basic_lstm_cell/Const_1
# n.name : main/rnn/while/basic_lstm_cell/split
# n.name : main/rnn/while/basic_lstm_cell/Const_2
# n.name : main/rnn/while/basic_lstm_cell/Add
# n.name : main/rnn/while/basic_lstm_cell/Sigmoid
# n.name : main/rnn/while/basic_lstm_cell/Mul
# n.name : main/rnn/while/basic_lstm_cell/Sigmoid_1
# n.name : main/rnn/while/basic_lstm_cell/Tanh
# n.name : main/rnn/while/basic_lstm_cell/Mul_1
# n.name : main/rnn/while/basic_lstm_cell/Add_1
# n.name : main/rnn/while/basic_lstm_cell/Tanh_1
# n.name : main/rnn/while/basic_lstm_cell/Sigmoid_2
# n.name : main/rnn/while/basic_lstm_cell/Mul_2
# n.name : main/rnn/while/TensorArrayWrite/TensorArrayWriteV3/Enter
# n.name : main/rnn/while/TensorArrayWrite/TensorArrayWriteV3
# n.name : main/rnn/while/add_1/y
# n.name : main/rnn/while/add_1
# n.name : main/rnn/while/NextIteration
# n.name : main/rnn/while/NextIteration_1
# n.name : main/rnn/while/NextIteration_2
# n.name : main/rnn/while/NextIteration_3
# n.name : main/rnn/while/NextIteration_4
# n.name : main/rnn/while/Exit
# n.name : main/rnn/while/Exit_1
# n.name : main/rnn/while/Exit_2
# n.name : main/rnn/while/Exit_3
# n.name : main/rnn/while/Exit_4
# n.name : main/rnn/TensorArrayStack/TensorArraySizeV3
# n.name : main/rnn/TensorArrayStack/range/start
# n.name : main/rnn/TensorArrayStack/range/delta
# n.name : main/rnn/TensorArrayStack/range
# n.name : main/rnn/TensorArrayStack/TensorArrayGatherV3
# n.name : main/rnn/Const_1
# n.name : main/rnn/Rank_1
# n.name : main/rnn/range_1/start
# n.name : main/rnn/range_1/delta
# n.name : main/rnn/range_1
# n.name : main/rnn/concat_2/values_0
# n.name : main/rnn/concat_2/axis
# n.name : main/rnn/concat_2
# n.name : main/rnn/transpose_1
# n.name : main/Reshape_2/shape
# n.name : main/Reshape_2
# n.name : main/Const
# n.name : main/split/split_dim
# n.name : main/split
# n.name : main/random_normal/shape
# n.name : main/random_normal/mean
# n.name : main/random_normal/stddev
# n.name : main/random_normal/RandomStandardNormal
# n.name : main/random_normal/mul
# n.name : main/random_normal
# n.name : main/Variable
# n.name : main/Variable/Assign
# n.name : main/Variable/read
# n.name : main/random_normal_1/shape
# n.name : main/random_normal_1/mean
# n.name : main/random_normal_1/stddev
# n.name : main/random_normal_1/RandomStandardNormal
# n.name : main/random_normal_1/mul
# n.name : main/random_normal_1
# n.name : main/Variable_1
# n.name : main/Variable_1/Assign
# n.name : main/Variable_1/read
# n.name : main/MatMul
# n.name : main/MatMul_1
# n.name : main/gradients/Shape
# n.name : main/gradients/grad_ys_0
# n.name : main/gradients/Fill
# n.name : main/gradients/f_count
# n.name : main/gradients/f_count_1
# n.name : main/gradients/Merge
# n.name : main/gradients/Switch
# n.name : main/gradients/Add/y
# n.name : main/gradients/Add
# n.name : main/gradients/f_count_2
# n.name : main/gradients/b_count
# n.name : main/gradients/b_count_1
# n.name : main/gradients/Merge_1
# n.name : main/gradients/GreaterEqual/Enter
# n.name : main/gradients/GreaterEqual
# n.name : main/gradients/b_count_2
# n.name : main/gradients/Switch_1
# n.name : main/gradients/Sub
# n.name : main/gradients/b_count_3
# n.name : main/gradients/main/MatMul_grad/MatMul
# n.name : main/gradients/main/MatMul_grad/MatMul_1
# n.name : main/gradients/zeros_like
# n.name : main/gradients/main/split_grad/concat
# n.name : main/gradients/main/Reshape_2_grad/Shape
# n.name : main/gradients/main/Reshape_2_grad/Reshape
# n.name : main/gradients/main/rnn/transpose_1_grad/InvertPermutation
# n.name : main/gradients/main/rnn/transpose_1_grad/transpose
# n.name : main/gradients/main/rnn/TensorArrayStack/TensorArrayGatherV3_grad/TensorArrayGrad/TensorArrayGradV3
# n.name : main/gradients/main/rnn/TensorArrayStack/TensorArrayGatherV3_grad/TensorArrayGrad/gradient_flow
# n.name : main/gradients/main/rnn/TensorArrayStack/TensorArrayGatherV3_grad/TensorArrayScatter/TensorArrayScatterV3
# n.name : main/gradients/zeros_like_1
# n.name : main/gradients/zeros_like_2
# n.name : main/gradients/main/rnn/while/Exit_2_grad/b_exit
# n.name : main/gradients/main/rnn/while/Exit_3_grad/b_exit
# n.name : main/gradients/main/rnn/while/Exit_4_grad/b_exit
# n.name : main/gradients/main/rnn/while/Switch_2_grad/b_switch
# n.name : main/gradients/main/rnn/while/Switch_3_grad/b_switch
# n.name : main/gradients/main/rnn/while/Switch_4_grad/b_switch
# n.name : main/gradients/main/rnn/while/Merge_2_grad/Switch
# n.name : main/gradients/main/rnn/while/Merge_3_grad/Switch
# n.name : main/gradients/main/rnn/while/Merge_4_grad/Switch
# n.name : main/gradients/main/rnn/while/Enter_2_grad/Exit
# n.name : main/gradients/main/rnn/while/Enter_3_grad/Exit
# n.name : main/gradients/main/rnn/while/Enter_4_grad/Exit
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayGrad/TensorArrayGradV3/Enter
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayGrad/TensorArrayGradV3
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayGrad/gradient_flow
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/Const
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/f_acc
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/Enter
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/StackPushV2
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/StackPopV2
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3
# n.name : main/gradients/AddN
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Shape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Shape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/Const_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/f_acc_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/Enter_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPushV2_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPopV2_1/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPopV2_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Sum
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Reshape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Sum_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_2_grad/Reshape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Tanh_1_grad/TanhGrad
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Sigmoid_2_grad/SigmoidGrad
# n.name : main/gradients/main/rnn/while/Switch_2_grad_1/NextIteration
# n.name : main/gradients/AddN_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/Shape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/Shape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/Const_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/f_acc_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/Enter_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPushV2_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPopV2_1/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPopV2_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/Sum
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/Reshape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/Sum_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_1_grad/Reshape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Shape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Shape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/Const_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/f_acc_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/Enter_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/StackPushV2_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/StackPopV2_1/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs/StackPopV2_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/BroadcastGradientArgs
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Sum
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Reshape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul_1/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul_1/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul_1/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul_1/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul_1/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul_1/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Mul_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Sum_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_grad/Reshape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Shape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Shape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/Const_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/f_acc_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/Enter_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/StackPushV2_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/StackPopV2_1/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs/StackPopV2_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/BroadcastGradientArgs
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Sum
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Reshape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul_1/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul_1/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul_1/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul_1/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul_1/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul_1/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Mul_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Sum_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Mul_1_grad/Reshape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Sigmoid_grad/SigmoidGrad
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Sigmoid_1_grad/SigmoidGrad
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Tanh_grad/TanhGrad
# n.name : main/gradients/main/rnn/while/Switch_3_grad_1/NextIteration
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/Shape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/Shape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/BroadcastGradientArgs/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/BroadcastGradientArgs/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/BroadcastGradientArgs/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/BroadcastGradientArgs/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/BroadcastGradientArgs/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/BroadcastGradientArgs/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/BroadcastGradientArgs
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/Sum
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/Reshape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/Sum_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/Add_grad/Reshape_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/split_grad/concat/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/split_grad/concat
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/BiasAdd_grad/BiasAddGrad
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/MatMul_grad/MatMul/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/MatMul_grad/MatMul
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/MatMul_grad/MatMul_1/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/MatMul_grad/MatMul_1/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/MatMul_grad/MatMul_1/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/MatMul_grad/MatMul_1/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/MatMul_grad/MatMul_1/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/MatMul_grad/MatMul_1/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/MatMul_grad/MatMul_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/Rank
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/mod
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/Shape
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/Const
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/f_acc
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPushV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPopV2/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPopV2
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/Const_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/f_acc_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/Enter_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPushV2_1
# n.name : main/gradients/NextIteration
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPopV2_1/Enter
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPopV2_1
# n.name : main/gradients/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/b_sync
# n.name : main/gradients/NextIteration_1
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ShapeN
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/ConcatOffset
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/Slice
# n.name : main/gradients/main/rnn/while/basic_lstm_cell/concat_grad/Slice_1
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3_grad/TensorArrayGrad/TensorArrayGradV3/Enter
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3_grad/TensorArrayGrad/TensorArrayGradV3/Enter_1
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3_grad/TensorArrayGrad/TensorArrayGradV3
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3_grad/TensorArrayGrad/gradient_flow
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3_grad/TensorArrayWrite/TensorArrayWriteV3
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3/Enter_1_grad/b_acc
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3/Enter_1_grad/b_acc_1
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3/Enter_1_grad/b_acc_2
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3/Enter_1_grad/Switch
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3/Enter_1_grad/Add
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3/Enter_1_grad/NextIteration
# n.name : main/gradients/main/rnn/while/TensorArrayReadV3/Enter_1_grad/b_acc_3
# n.name : main/gradients/main/rnn/while/Switch_4_grad_1/NextIteration
# n.name : main/gradients/main/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3_grad/TensorArrayGrad/TensorArrayGradV3
# n.name : main/gradients/main/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3_grad/TensorArrayGrad/gradient_flow
# n.name : main/gradients/main/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3_grad/TensorArrayGatherV3
# n.name : main/gradients/main/rnn/transpose_grad/InvertPermutation
# n.name : main/gradients/main/rnn/transpose_grad/transpose
# n.name : main/gradients/main/Reshape_1_grad/Shape
# n.name : main/gradients/main/Reshape_1_grad/Reshape
# n.name : main/gradients/main/Flatten/flatten/Reshape_grad/Shape
# n.name : main/gradients/main/Flatten/flatten/Reshape_grad/Reshape
# n.name : main/gradients/main/Conv_3/Relu_grad/ReluGrad
# n.name : main/gradients/main/Conv_3/Conv2D_grad/ShapeN
# n.name : main/gradients/main/Conv_3/Conv2D_grad/Conv2DBackpropInput
# n.name : main/gradients/main/Conv_3/Conv2D_grad/Conv2DBackpropFilter
# n.name : main/gradients/main/Conv_2/Relu_grad/ReluGrad
# n.name : main/gradients/main/Conv_2/Conv2D_grad/ShapeN
# n.name : main/gradients/main/Conv_2/Conv2D_grad/Conv2DBackpropInput
# n.name : main/gradients/main/Conv_2/Conv2D_grad/Conv2DBackpropFilter
# n.name : main/gradients/main/Conv_1/Relu_grad/ReluGrad
# n.name : main/gradients/main/Conv_1/Conv2D_grad/ShapeN
# n.name : main/gradients/main/Conv_1/Conv2D_grad/Conv2DBackpropInput
# n.name : main/gradients/main/Conv_1/Conv2D_grad/Conv2DBackpropFilter
# n.name : main/gradients/main/Conv/Relu_grad/ReluGrad
# n.name : main/gradients/main/Conv/Conv2D_grad/ShapeN
# n.name : main/gradients/main/Conv/Conv2D_grad/Conv2DBackpropInput
# n.name : main/gradients/main/Conv/Conv2D_grad/Conv2DBackpropFilter
# n.name : main/Mean/reduction_indices
# n.name : main/Mean
# n.name : main/Sub
# n.name : main/add
# n.name : main/ArgMax/dimension
# n.name : main/ArgMax
# n.name : main/targetQ
# n.name : main/actions
# n.name : main/one_hot/on_value
# n.name : main/one_hot/off_value
# n.name : main/one_hot/depth
# n.name : main/one_hot
# n.name : main/Mul
# n.name : main/Sum/reduction_indices
# n.name : main/Sum
# n.name : main/sub_1
# n.name : main/Square
# n.name : main/floordiv/y
# n.name : main/floordiv
# n.name : main/zeros/mul
# n.name : main/zeros/Less/y
# n.name : main/zeros/Less
# n.name : main/zeros/packed
# n.name : main/zeros/Const
# n.name : main/zeros
# n.name : main/floordiv_1/y
# n.name : main/floordiv_1
# n.name : main/ones/mul
# n.name : main/ones/Less/y
# n.name : main/ones/Less
# n.name : main/ones/packed
# n.name : main/ones/Const
# n.name : main/ones
# n.name : main/concat/axis
# n.name : main/concat
# n.name : main/Reshape_3/shape
# n.name : main/Reshape_3
# n.name : main/mul_1
# n.name : main/Const_1
# n.name : main/Mean_1
# n.name : main/gradients_1/Shape
# n.name : main/gradients_1/grad_ys_0
# n.name : main/gradients_1/Fill
# n.name : main/gradients_1/f_count
# n.name : main/gradients_1/f_count_1
# n.name : main/gradients_1/Merge
# n.name : main/gradients_1/Switch
# n.name : main/gradients_1/Add/y
# n.name : main/gradients_1/Add
# n.name : main/gradients_1/f_count_2
# n.name : main/gradients_1/b_count
# n.name : main/gradients_1/b_count_1
# n.name : main/gradients_1/Merge_1
# n.name : main/gradients_1/GreaterEqual/Enter
# n.name : main/gradients_1/GreaterEqual
# n.name : main/gradients_1/b_count_2
# n.name : main/gradients_1/Switch_1
# n.name : main/gradients_1/Sub
# n.name : main/gradients_1/b_count_3
# n.name : main/gradients_1/main/Mean_1_grad/Reshape/shape
# n.name : main/gradients_1/main/Mean_1_grad/Reshape
# n.name : main/gradients_1/main/Mean_1_grad/Shape
# n.name : main/gradients_1/main/Mean_1_grad/Tile
# n.name : main/gradients_1/main/Mean_1_grad/Shape_1
# n.name : main/gradients_1/main/Mean_1_grad/Shape_2
# n.name : main/gradients_1/main/Mean_1_grad/Const
# n.name : main/gradients_1/main/Mean_1_grad/Prod
# n.name : main/gradients_1/main/Mean_1_grad/Const_1
# n.name : main/gradients_1/main/Mean_1_grad/Prod_1
# n.name : main/gradients_1/main/Mean_1_grad/Maximum/y
# n.name : main/gradients_1/main/Mean_1_grad/Maximum
# n.name : main/gradients_1/main/Mean_1_grad/floordiv
# n.name : main/gradients_1/main/Mean_1_grad/Cast
# n.name : main/gradients_1/main/Mean_1_grad/truediv
# n.name : main/gradients_1/main/mul_1_grad/Shape
# n.name : main/gradients_1/main/mul_1_grad/Shape_1
# n.name : main/gradients_1/main/mul_1_grad/BroadcastGradientArgs
# n.name : main/gradients_1/main/mul_1_grad/Mul
# n.name : main/gradients_1/main/mul_1_grad/Sum
# n.name : main/gradients_1/main/mul_1_grad/Reshape
# n.name : main/gradients_1/main/mul_1_grad/Mul_1
# n.name : main/gradients_1/main/mul_1_grad/Sum_1
# n.name : main/gradients_1/main/mul_1_grad/Reshape_1
# n.name : main/gradients_1/main/mul_1_grad/tuple/group_deps
# n.name : main/gradients_1/main/mul_1_grad/tuple/control_dependency
# n.name : main/gradients_1/main/mul_1_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/Square_grad/Const
# n.name : main/gradients_1/main/Square_grad/Mul
# n.name : main/gradients_1/main/Square_grad/Mul_1
# n.name : main/gradients_1/main/sub_1_grad/Shape
# n.name : main/gradients_1/main/sub_1_grad/Shape_1
# n.name : main/gradients_1/main/sub_1_grad/BroadcastGradientArgs
# n.name : main/gradients_1/main/sub_1_grad/Sum
# n.name : main/gradients_1/main/sub_1_grad/Reshape
# n.name : main/gradients_1/main/sub_1_grad/Sum_1
# n.name : main/gradients_1/main/sub_1_grad/Neg
# n.name : main/gradients_1/main/sub_1_grad/Reshape_1
# n.name : main/gradients_1/main/sub_1_grad/tuple/group_deps
# n.name : main/gradients_1/main/sub_1_grad/tuple/control_dependency
# n.name : main/gradients_1/main/sub_1_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/Sum_grad/Shape
# n.name : main/gradients_1/main/Sum_grad/Size
# n.name : main/gradients_1/main/Sum_grad/add
# n.name : main/gradients_1/main/Sum_grad/mod
# n.name : main/gradients_1/main/Sum_grad/Shape_1
# n.name : main/gradients_1/main/Sum_grad/range/start
# n.name : main/gradients_1/main/Sum_grad/range/delta
# n.name : main/gradients_1/main/Sum_grad/range
# n.name : main/gradients_1/main/Sum_grad/Fill/value
# n.name : main/gradients_1/main/Sum_grad/Fill
# n.name : main/gradients_1/main/Sum_grad/DynamicStitch
# n.name : main/gradients_1/main/Sum_grad/Maximum/y
# n.name : main/gradients_1/main/Sum_grad/Maximum
# n.name : main/gradients_1/main/Sum_grad/floordiv
# n.name : main/gradients_1/main/Sum_grad/Reshape
# n.name : main/gradients_1/main/Sum_grad/Tile
# n.name : main/gradients_1/main/Mul_grad/Shape
# n.name : main/gradients_1/main/Mul_grad/Shape_1
# n.name : main/gradients_1/main/Mul_grad/BroadcastGradientArgs
# n.name : main/gradients_1/main/Mul_grad/Mul
# n.name : main/gradients_1/main/Mul_grad/Sum
# n.name : main/gradients_1/main/Mul_grad/Reshape
# n.name : main/gradients_1/main/Mul_grad/Mul_1
# n.name : main/gradients_1/main/Mul_grad/Sum_1
# n.name : main/gradients_1/main/Mul_grad/Reshape_1
# n.name : main/gradients_1/main/Mul_grad/tuple/group_deps
# n.name : main/gradients_1/main/Mul_grad/tuple/control_dependency
# n.name : main/gradients_1/main/Mul_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/add_grad/Shape
# n.name : main/gradients_1/main/add_grad/Shape_1
# n.name : main/gradients_1/main/add_grad/BroadcastGradientArgs
# n.name : main/gradients_1/main/add_grad/Sum
# n.name : main/gradients_1/main/add_grad/Reshape
# n.name : main/gradients_1/main/add_grad/Sum_1
# n.name : main/gradients_1/main/add_grad/Reshape_1
# n.name : main/gradients_1/main/add_grad/tuple/group_deps
# n.name : main/gradients_1/main/add_grad/tuple/control_dependency
# n.name : main/gradients_1/main/add_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/MatMul_1_grad/MatMul
# n.name : main/gradients_1/main/MatMul_1_grad/MatMul_1
# n.name : main/gradients_1/main/MatMul_1_grad/tuple/group_deps
# n.name : main/gradients_1/main/MatMul_1_grad/tuple/control_dependency
# n.name : main/gradients_1/main/MatMul_1_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/Sub_grad/Shape
# n.name : main/gradients_1/main/Sub_grad/Shape_1
# n.name : main/gradients_1/main/Sub_grad/BroadcastGradientArgs
# n.name : main/gradients_1/main/Sub_grad/Sum
# n.name : main/gradients_1/main/Sub_grad/Reshape
# n.name : main/gradients_1/main/Sub_grad/Sum_1
# n.name : main/gradients_1/main/Sub_grad/Neg
# n.name : main/gradients_1/main/Sub_grad/Reshape_1
# n.name : main/gradients_1/main/Sub_grad/tuple/group_deps
# n.name : main/gradients_1/main/Sub_grad/tuple/control_dependency
# n.name : main/gradients_1/main/Sub_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/Mean_grad/Shape
# n.name : main/gradients_1/main/Mean_grad/Size
# n.name : main/gradients_1/main/Mean_grad/add
# n.name : main/gradients_1/main/Mean_grad/mod
# n.name : main/gradients_1/main/Mean_grad/Shape_1
# n.name : main/gradients_1/main/Mean_grad/range/start
# n.name : main/gradients_1/main/Mean_grad/range/delta
# n.name : main/gradients_1/main/Mean_grad/range
# n.name : main/gradients_1/main/Mean_grad/Fill/value
# n.name : main/gradients_1/main/Mean_grad/Fill
# n.name : main/gradients_1/main/Mean_grad/DynamicStitch
# n.name : main/gradients_1/main/Mean_grad/Maximum/y
# n.name : main/gradients_1/main/Mean_grad/Maximum
# n.name : main/gradients_1/main/Mean_grad/floordiv
# n.name : main/gradients_1/main/Mean_grad/Reshape
# n.name : main/gradients_1/main/Mean_grad/Tile
# n.name : main/gradients_1/main/Mean_grad/Shape_2
# n.name : main/gradients_1/main/Mean_grad/Shape_3
# n.name : main/gradients_1/main/Mean_grad/Const
# n.name : main/gradients_1/main/Mean_grad/Prod
# n.name : main/gradients_1/main/Mean_grad/Const_1
# n.name : main/gradients_1/main/Mean_grad/Prod_1
# n.name : main/gradients_1/main/Mean_grad/Maximum_1/y
# n.name : main/gradients_1/main/Mean_grad/Maximum_1
# n.name : main/gradients_1/main/Mean_grad/floordiv_1
# n.name : main/gradients_1/main/Mean_grad/Cast
# n.name : main/gradients_1/main/Mean_grad/truediv
# n.name : main/gradients_1/AddN
# n.name : main/gradients_1/main/MatMul_grad/MatMul
# n.name : main/gradients_1/main/MatMul_grad/MatMul_1
# n.name : main/gradients_1/main/MatMul_grad/tuple/group_deps
# n.name : main/gradients_1/main/MatMul_grad/tuple/control_dependency
# n.name : main/gradients_1/main/MatMul_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/split_grad/concat
# n.name : main/gradients_1/main/Reshape_2_grad/Shape
# n.name : main/gradients_1/main/Reshape_2_grad/Reshape
# n.name : main/gradients_1/main/rnn/transpose_1_grad/InvertPermutation
# n.name : main/gradients_1/main/rnn/transpose_1_grad/transpose
# n.name : main/gradients_1/main/rnn/TensorArrayStack/TensorArrayGatherV3_grad/TensorArrayGrad/TensorArrayGradV3
# n.name : main/gradients_1/main/rnn/TensorArrayStack/TensorArrayGatherV3_grad/TensorArrayGrad/gradient_flow
# n.name : main/gradients_1/main/rnn/TensorArrayStack/TensorArrayGatherV3_grad/TensorArrayScatter/TensorArrayScatterV3
# n.name : main/gradients_1/zeros_like
# n.name : main/gradients_1/zeros_like_1
# n.name : main/gradients_1/main/rnn/while/Exit_2_grad/b_exit
# n.name : main/gradients_1/main/rnn/while/Exit_3_grad/b_exit
# n.name : main/gradients_1/main/rnn/while/Exit_4_grad/b_exit
# n.name : main/gradients_1/main/rnn/while/Switch_2_grad/b_switch
# n.name : main/gradients_1/main/rnn/while/Switch_3_grad/b_switch
# n.name : main/gradients_1/main/rnn/while/Switch_4_grad/b_switch
# n.name : main/gradients_1/main/rnn/while/Merge_2_grad/Switch
# n.name : main/gradients_1/main/rnn/while/Merge_2_grad/tuple/group_deps
# n.name : main/gradients_1/main/rnn/while/Merge_2_grad/tuple/control_dependency
# n.name : main/gradients_1/main/rnn/while/Merge_2_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/rnn/while/Merge_3_grad/Switch
# n.name : main/gradients_1/main/rnn/while/Merge_3_grad/tuple/group_deps
# n.name : main/gradients_1/main/rnn/while/Merge_3_grad/tuple/control_dependency
# n.name : main/gradients_1/main/rnn/while/Merge_3_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/rnn/while/Merge_4_grad/Switch
# n.name : main/gradients_1/main/rnn/while/Merge_4_grad/tuple/group_deps
# n.name : main/gradients_1/main/rnn/while/Merge_4_grad/tuple/control_dependency
# n.name : main/gradients_1/main/rnn/while/Merge_4_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/rnn/while/Enter_2_grad/Exit
# n.name : main/gradients_1/main/rnn/while/Enter_3_grad/Exit
# n.name : main/gradients_1/main/rnn/while/Enter_4_grad/Exit
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayGrad/TensorArrayGradV3/Enter
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayGrad/TensorArrayGradV3
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayGrad/gradient_flow
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/Const
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/f_acc
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/Enter
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/StackPushV2
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/StackPopV2/Enter
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/StackPopV2
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/tuple/group_deps
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/tuple/control_dependency
# n.name : main/gradients_1/main/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/tuple/control_dependency_1
# n.name : main/gradients_1/AddN_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Shape
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Shape_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/Const
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/f_acc
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPushV2
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPopV2/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPopV2
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/Const_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/f_acc_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/Enter_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPushV2_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPopV2_1/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs/StackPopV2_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/BroadcastGradientArgs
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/Const
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/f_acc
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/StackPushV2
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/StackPopV2/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul/StackPopV2
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Sum
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Reshape
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/Const
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/f_acc
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/StackPushV2
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/StackPopV2/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1/StackPopV2
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Mul_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Sum_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/Reshape_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/tuple/group_deps
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/tuple/control_dependency
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Mul_2_grad/tuple/control_dependency_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Tanh_1_grad/TanhGrad
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Sigmoid_2_grad/SigmoidGrad
# n.name : main/gradients_1/main/rnn/while/Switch_2_grad_1/NextIteration
# n.name : main/gradients_1/AddN_2
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/Shape
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/Shape_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/Const
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/f_acc
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPushV2
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPopV2/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPopV2
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/Const_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/f_acc_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/Enter_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPushV2_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPopV2_1/Enter
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs/StackPopV2_1
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/BroadcastGradientArgs
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/Sum
# n.name : main/gradients_1/main/rnn/while/basic_lstm_cell/Add_1_grad/Reshape
# ...
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/mod
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/Shape
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/Const
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/f_acc
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/Enter
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPushV2
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPopV2/Enter
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPopV2
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/Const_1
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/f_acc_1
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/Enter_1
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPushV2_1
# n.name : target/gradients_1/NextIteration
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPopV2_1/Enter
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN/StackPopV2_1
# n.name : target/gradients_1/target/rnn/while/TensorArrayWrite/TensorArrayWriteV3_grad/TensorArrayReadV3/b_sync
# n.name : target/gradients_1/NextIteration_1
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ShapeN
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/ConcatOffset
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/Slice
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/Slice_1
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/tuple/group_deps
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/tuple/control_dependency
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/concat_grad/tuple/control_dependency_1
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/MatMul/Enter_grad/b_acc
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/MatMul/Enter_grad/b_acc_1
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/MatMul/Enter_grad/b_acc_2
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/MatMul/Enter_grad/Switch
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/MatMul/Enter_grad/Add
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/MatMul/Enter_grad/NextIteration
# n.name : target/gradients_1/target/rnn/while/basic_lstm_cell/MatMul/Enter_grad/b_acc_3
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3_grad/TensorArrayGrad/TensorArrayGradV3/Enter
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3_grad/TensorArrayGrad/TensorArrayGradV3/Enter_1
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3_grad/TensorArrayGrad/TensorArrayGradV3
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3_grad/TensorArrayGrad/gradient_flow
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3_grad/TensorArrayWrite/TensorArrayWriteV3
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3/Enter_1_grad/b_acc
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3/Enter_1_grad/b_acc_1
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3/Enter_1_grad/b_acc_2
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3/Enter_1_grad/Switch
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3/Enter_1_grad/Add
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3/Enter_1_grad/NextIteration
# n.name : target/gradients_1/target/rnn/while/TensorArrayReadV3/Enter_1_grad/b_acc_3
# n.name : target/gradients_1/target/rnn/while/Switch_4_grad_1/NextIteration
# n.name : target/gradients_1/target/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3_grad/TensorArrayGrad/TensorArrayGradV3
# n.name : target/gradients_1/target/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3_grad/TensorArrayGrad/gradient_flow
# n.name : target/gradients_1/target/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3_grad/TensorArrayGatherV3
# n.name : target/gradients_1/target/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3_grad/tuple/group_deps
# n.name : target/gradients_1/target/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3_grad/tuple/control_dependency
# n.name : target/gradients_1/target/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3_grad/tuple/control_dependency_1
# n.name : target/gradients_1/target/rnn/transpose_grad/InvertPermutation
# n.name : target/gradients_1/target/rnn/transpose_grad/transpose
# n.name : target/gradients_1/target/Reshape_1_grad/Shape
# n.name : target/gradients_1/target/Reshape_1_grad/Reshape
# n.name : target/gradients_1/target/Flatten/flatten/Reshape_grad/Shape
# n.name : target/gradients_1/target/Flatten/flatten/Reshape_grad/Reshape
# n.name : target/gradients_1/target/Conv_3/Relu_grad/ReluGrad
# n.name : target/gradients_1/target/Conv_3/Conv2D_grad/ShapeN
# n.name : target/gradients_1/target/Conv_3/Conv2D_grad/Conv2DBackpropInput
# n.name : target/gradients_1/target/Conv_3/Conv2D_grad/Conv2DBackpropFilter
# n.name : target/gradients_1/target/Conv_3/Conv2D_grad/tuple/group_deps
# n.name : target/gradients_1/target/Conv_3/Conv2D_grad/tuple/control_dependency
# n.name : target/gradients_1/target/Conv_3/Conv2D_grad/tuple/control_dependency_1
# n.name : target/gradients_1/target/Conv_2/Relu_grad/ReluGrad
# n.name : target/gradients_1/target/Conv_2/Conv2D_grad/ShapeN
# n.name : target/gradients_1/target/Conv_2/Conv2D_grad/Conv2DBackpropInput
# n.name : target/gradients_1/target/Conv_2/Conv2D_grad/Conv2DBackpropFilter
# n.name : target/gradients_1/target/Conv_2/Conv2D_grad/tuple/group_deps
# n.name : target/gradients_1/target/Conv_2/Conv2D_grad/tuple/control_dependency
# n.name : target/gradients_1/target/Conv_2/Conv2D_grad/tuple/control_dependency_1
# n.name : target/gradients_1/target/Conv_1/Relu_grad/ReluGrad
# n.name : target/gradients_1/target/Conv_1/Conv2D_grad/ShapeN
# n.name : target/gradients_1/target/Conv_1/Conv2D_grad/Conv2DBackpropInput
# n.name : target/gradients_1/target/Conv_1/Conv2D_grad/Conv2DBackpropFilter
# n.name : target/gradients_1/target/Conv_1/Conv2D_grad/tuple/group_deps
# n.name : target/gradients_1/target/Conv_1/Conv2D_grad/tuple/control_dependency
# n.name : target/gradients_1/target/Conv_1/Conv2D_grad/tuple/control_dependency_1
# n.name : target/gradients_1/target/Conv/Relu_grad/ReluGrad
# n.name : target/gradients_1/target/Conv/Conv2D_grad/ShapeN
# n.name : target/gradients_1/target/Conv/Conv2D_grad/Conv2DBackpropInput
# n.name : target/gradients_1/target/Conv/Conv2D_grad/Conv2DBackpropFilter
# n.name : target/gradients_1/target/Conv/Conv2D_grad/tuple/group_deps
# n.name : target/gradients_1/target/Conv/Conv2D_grad/tuple/control_dependency
# n.name : target/gradients_1/target/Conv/Conv2D_grad/tuple/control_dependency_1
# n.name : target/beta1_power/initial_value
# n.name : target/beta1_power
# n.name : target/beta1_power/Assign
# n.name : target/beta1_power/read
# n.name : target/beta2_power/initial_value
# n.name : target/beta2_power
# n.name : target/beta2_power/Assign
# n.name : target/beta2_power/read
# n.name : target/target/Conv/weights/Adam/Initializer/zeros/shape_as_tensor
# n.name : target/target/Conv/weights/Adam/Initializer/zeros/Const
# n.name : target/target/Conv/weights/Adam/Initializer/zeros
# n.name : target/target/Conv/weights/Adam
# n.name : target/target/Conv/weights/Adam/Assign
# n.name : target/target/Conv/weights/Adam/read
# n.name : target/target/Conv/weights/Adam_1/Initializer/zeros/shape_as_tensor
# n.name : target/target/Conv/weights/Adam_1/Initializer/zeros/Const
# n.name : target/target/Conv/weights/Adam_1/Initializer/zeros
# n.name : target/target/Conv/weights/Adam_1
# n.name : target/target/Conv/weights/Adam_1/Assign
# n.name : target/target/Conv/weights/Adam_1/read
# n.name : target/target/Conv_1/weights/Adam/Initializer/zeros/shape_as_tensor
# n.name : target/target/Conv_1/weights/Adam/Initializer/zeros/Const
# n.name : target/target/Conv_1/weights/Adam/Initializer/zeros
# n.name : target/target/Conv_1/weights/Adam
# n.name : target/target/Conv_1/weights/Adam/Assign
# n.name : target/target/Conv_1/weights/Adam/read
# n.name : target/target/Conv_1/weights/Adam_1/Initializer/zeros/shape_as_tensor
# n.name : target/target/Conv_1/weights/Adam_1/Initializer/zeros/Const
# n.name : target/target/Conv_1/weights/Adam_1/Initializer/zeros
# n.name : target/target/Conv_1/weights/Adam_1
# n.name : target/target/Conv_1/weights/Adam_1/Assign
# n.name : target/target/Conv_1/weights/Adam_1/read
# n.name : target/target/Conv_2/weights/Adam/Initializer/zeros/shape_as_tensor
# n.name : target/target/Conv_2/weights/Adam/Initializer/zeros/Const
# n.name : target/target/Conv_2/weights/Adam/Initializer/zeros
# n.name : target/target/Conv_2/weights/Adam
# n.name : target/target/Conv_2/weights/Adam/Assign
# n.name : target/target/Conv_2/weights/Adam/read
# n.name : target/target/Conv_2/weights/Adam_1/Initializer/zeros/shape_as_tensor
# n.name : target/target/Conv_2/weights/Adam_1/Initializer/zeros/Const
# n.name : target/target/Conv_2/weights/Adam_1/Initializer/zeros
# n.name : target/target/Conv_2/weights/Adam_1
# n.name : target/target/Conv_2/weights/Adam_1/Assign
# n.name : target/target/Conv_2/weights/Adam_1/read
# n.name : target/target/Conv_3/weights/Adam/Initializer/zeros/shape_as_tensor
# n.name : target/target/Conv_3/weights/Adam/Initializer/zeros/Const
# n.name : target/target/Conv_3/weights/Adam/Initializer/zeros
# n.name : target/target/Conv_3/weights/Adam
# n.name : target/target/Conv_3/weights/Adam/Assign
# n.name : target/target/Conv_3/weights/Adam/read
# n.name : target/target/Conv_3/weights/Adam_1/Initializer/zeros/shape_as_tensor
# n.name : target/target/Conv_3/weights/Adam_1/Initializer/zeros/Const
# n.name : target/target/Conv_3/weights/Adam_1/Initializer/zeros
# n.name : target/target/Conv_3/weights/Adam_1
# n.name : target/target/Conv_3/weights/Adam_1/Assign
# n.name : target/target/Conv_3/weights/Adam_1/read
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam/Initializer/zeros/shape_as_tensor
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam/Initializer/zeros/Const
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam/Initializer/zeros
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam/Assign
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam/read
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam_1/Initializer/zeros/Const
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam_1/Initializer/zeros
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam_1
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam_1/Assign
# n.name : target/target/rnn/basic_lstm_cell/kernel/Adam_1/read
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam/Initializer/zeros/shape_as_tensor
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam/Initializer/zeros/Const
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam/Initializer/zeros
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam/Assign
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam/read
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam_1/Initializer/zeros/shape_as_tensor
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam_1/Initializer/zeros/Const
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam_1/Initializer/zeros
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam_1
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam_1/Assign
# n.name : target/target/rnn/basic_lstm_cell/bias/Adam_1/read
# n.name : target/target/Variable/Adam/Initializer/zeros/shape_as_tensor
# n.name : target/target/Variable/Adam/Initializer/zeros/Const
# n.name : target/target/Variable/Adam/Initializer/zeros
# n.name : target/target/Variable/Adam
# n.name : target/target/Variable/Adam/Assign
# n.name : target/target/Variable/Adam/read
# n.name : target/target/Variable/Adam_1/Initializer/zeros/shape_as_tensor
# n.name : target/target/Variable/Adam_1/Initializer/zeros/Const
# n.name : target/target/Variable/Adam_1/Initializer/zeros
# n.name : target/target/Variable/Adam_1
# n.name : target/target/Variable/Adam_1/Assign
# n.name : target/target/Variable/Adam_1/read
# n.name : target/target/Variable_1/Adam/Initializer/zeros
# n.name : target/target/Variable_1/Adam
# n.name : target/target/Variable_1/Adam/Assign
# n.name : target/target/Variable_1/Adam/read
# n.name : target/target/Variable_1/Adam_1/Initializer/zeros
# n.name : target/target/Variable_1/Adam_1
# n.name : target/target/Variable_1/Adam_1/Assign
# n.name : target/target/Variable_1/Adam_1/read
# n.name : target/Adam/learning_rate
# n.name : target/Adam/beta1
# n.name : target/Adam/beta2
# n.name : target/Adam/epsilon
# n.name : target/Adam/update_target/Conv/weights/ApplyAdam
# n.name : target/Adam/update_target/Conv_1/weights/ApplyAdam
# n.name : target/Adam/update_target/Conv_2/weights/ApplyAdam
# n.name : target/Adam/update_target/Conv_3/weights/ApplyAdam
# n.name : target/Adam/update_target/rnn/basic_lstm_cell/kernel/ApplyAdam
# n.name : target/Adam/update_target/rnn/basic_lstm_cell/bias/ApplyAdam
# n.name : target/Adam/update_target/Variable/ApplyAdam
# n.name : target/Adam/update_target/Variable_1/ApplyAdam
# n.name : target/Adam/mul
# n.name : target/Adam/Assign
# n.name : target/Adam/mul_1
# n.name : target/Adam/Assign_1
# n.name : target/Adam
# n.name : init
# n.name : save/filename/input
# n.name : save/filename
# n.name : save/Const
# n.name : save/SaveV2/tensor_names
# n.name : save/SaveV2/shape_and_slices
# n.name : save/SaveV2
# n.name : save/control_dependency
# n.name : save/RestoreV2/tensor_names
# n.name : save/RestoreV2/shape_and_slices
# n.name : save/RestoreV2
# n.name : save/Assign
# n.name : save/Assign_1
# n.name : save/Assign_2
# n.name : save/Assign_3
# n.name : save/Assign_4
# n.name : save/Assign_5
# n.name : save/Assign_6
# n.name : save/Assign_7
# n.name : save/Assign_8
# n.name : save/Assign_9
# n.name : save/Assign_10
# n.name : save/Assign_11
# n.name : save/Assign_12
# n.name : save/Assign_13
# n.name : save/Assign_14
# n.name : save/Assign_15
# n.name : save/Assign_16
# n.name : save/Assign_17
# n.name : save/Assign_18
# n.name : save/Assign_19
# n.name : save/Assign_20
# n.name : save/Assign_21
# n.name : save/Assign_22
# n.name : save/Assign_23
# n.name : save/Assign_24
# n.name : save/Assign_25
# n.name : save/Assign_26
# n.name : save/Assign_27
# n.name : save/Assign_28
# n.name : save/Assign_29
# n.name : save/Assign_30
# n.name : save/Assign_31
# n.name : save/Assign_32
# n.name : save/Assign_33
# n.name : save/Assign_34
# n.name : save/Assign_35
# n.name : save/Assign_36
# n.name : save/Assign_37
# n.name : save/Assign_38
# n.name : save/Assign_39
# n.name : save/Assign_40
# n.name : save/Assign_41
# n.name : save/Assign_42
# n.name : save/Assign_43
# n.name : save/Assign_44
# n.name : save/Assign_45
# n.name : save/Assign_46
# n.name : save/Assign_47
# n.name : save/Assign_48
# n.name : save/Assign_49
# n.name : save/Assign_50
# n.name : save/Assign_51
# n.name : save/restore_all
# n.name : mul/y
# n.name : mul
# n.name : mul_1/x
# n.name : mul_1
# n.name : add
# n.name : Assign
# n.name : mul_2/y
# n.name : mul_2
# n.name : mul_3/x
# n.name : mul_3
# n.name : add_1
# n.name : Assign_1
# n.name : mul_4/y
# n.name : mul_4
# n.name : mul_5/x
# n.name : mul_5
# n.name : add_2
# n.name : Assign_2
# n.name : mul_6/y
# n.name : mul_6
# n.name : mul_7/x
# n.name : mul_7
# n.name : add_3
# n.name : Assign_3
# n.name : mul_8/y
# n.name : mul_8
# n.name : mul_9/x
# n.name : mul_9
# n.name : add_4
# n.name : Assign_4
# n.name : mul_10/y
# n.name : mul_10
# n.name : mul_11/x
# n.name : mul_11
# n.name : add_5
# n.name : Assign_5
# n.name : mul_12/y
# n.name : mul_12
# n.name : mul_13/x
# n.name : mul_13
# n.name : add_6
# n.name : Assign_6
# n.name : mul_14/y
# n.name : mul_14
# n.name : mul_15/x
# n.name : mul_15
# n.name : add_7
# n.name : Assign_7
# INFO:tensorflow:Froze 8 variables.
# INFO:tensorflow:Converted 8 variables to const ops.
# 168 ops in the final graph.

# %%
import tensorflow as tf
import numpy as np

def load_graph(frozen_graph_filename):
    # We load the protobuf file from the disk and parse it to retrieve the 
    # unserialized graph_def
    with tf.gfile.GFile(frozen_graph_filename, "rb") as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())

    # Then, we import the graph_def into a new Graph and returns it 
    with tf.Graph().as_default() as graph:
        # The name var will prefix every op/nodes in your graph
        # Since we load everything in a new graph, this is not needed
        tf.import_graph_def(graph_def, name="prefix")
        
    return graph

if __name__ == '__main__':
    # Let's allow the user to pass the filename as an argument
    frozen_model_filename = "/home/kimbring2/catkin_ws/src/jetbot/jetbot_control/src/drqn/frozen_model.pb"
    
    # We use our "load_graph" function
    graph = load_graph(frozen_model_filename)

    # We can verify that we can access the list of operations in the graph
    #for op in graph.get_operations():
    #    print(op.name)
        
    # We access the input and output nodes 
    x = graph.get_tensor_by_name('prefix/main/scalarInput:0')
    y = graph.get_tensor_by_name('prefix/main/ArgMax:0')
    trainLength = graph.get_tensor_by_name('prefix/main/trainLength:0')
    batch_size = graph.get_tensor_by_name('prefix/main/batch_size:0')
    
    input_test = np.empty([84, 84, 3], dtype=float)
    input_test_flatten = input_test.flatten()
    
    # We launch a Session
    with tf.Session(graph=graph) as sess:
        # Note: we don't nee to initialize/restore anything
        # There is no Variables in this graph, only hardcoded constants 
        y_out = sess.run(y, feed_dict={
            x: [input_test_flatten],
            trainLength: 1,
            batch_size: 1
        })
        # I taught a neural net to recognise when a sum of numbers is bigger than 45
        # it should return False in this case
        print(y_out) # [[ False ]] Yay, it works!
# Out:
# [4]
